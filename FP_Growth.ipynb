# %%
import pandas as pd
import mlxtend
from mlxtend.frequent_patterns import fpgrowth, association_rules

retail = pd.read_csv('Online_Retail.csv')

retail['CustomerID'] = retail['CustomerID'].fillna(method='ffill')
retail.dropna(inplace=True)

retail = retail[(retail['Quantity'] > 0) & (retail['UnitPrice'] > 0)]

basket = (retail.groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

def encode(x):
    return 1 if x > 0 else 0

basket = basket.map(encode)
# Out:
# C:\Users\darre\AppData\Local\Temp\ipykernel_96616\655568778.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   retail['CustomerID'] = retail['CustomerID'].fillna(method='ffill')

# %%
frequent_itemsets = fpgrowth(basket, min_support=0.02, use_colnames=True)

print("Frequent Itemsets:")
print(frequent_itemsets.tail(20))
# Out:
# C:\Users\darre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets:
#       support  \
# 358  0.021493
# 359  0.031663
# 360  0.029960
# 361  0.027104
# 362  0.020541
# 363  0.027856
# 364  0.023597
# 365  0.022796
# 366  0.020792
# 367  0.025802
# 368  0.022445
# 369  0.024399
# 370  0.022495
# 371  0.020792
# 372  0.027355
# 373  0.020741
# 374  0.024198
# 375  0.021293
# 376  0.020341
# 377  0.027355
#
#                                                                                                 itemsets
# 358                                                 (JUMBO BAG SPACEBOY DESIGN, JUMBO BAG RED RETROSPOT)
# 359                                    (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY TEACUP AND SAUCER)
# 360                                   (ROSES REGENCY TEACUP AND SAUCER , PINK REGENCY TEACUP AND SAUCER)
# 361  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENCY TEACUP AND SAUCER , PINK REGENCY TEACUP AND SAUCER)
# 362                               (SET OF 6 SPICE TINS PANTRY DESIGN, SET OF 3 CAKE TINS PANTRY DESIGN )
# 363                                                    (LUNCH BAG SUKI DESIGN , LUNCH BAG RED RETROSPOT)
# 364                                                        (LUNCH BAG SUKI DESIGN , LUNCH BAG CARS BLUE)
# 365                                                 (LUNCH BAG SUKI DESIGN , LUNCH BAG SPACEBOY DESIGN )
# 366                                                    (LUNCH BAG SUKI DESIGN , LUNCH BAG PINK POLKADOT)
# 367                                                    (LUNCH BAG  BLACK SKULL., LUNCH BAG SUKI DESIGN )
# 368                                       (JUMBO BAG RED RETROSPOT, JUMBO BAG SCANDINAVIAN BLUE PAISLEY)
# 369                                                    (LUNCH BAG APPLE DESIGN, LUNCH BAG RED RETROSPOT)
# 370                                                     (LUNCH BAG SUKI DESIGN , LUNCH BAG APPLE DESIGN)
# 371                                                    (LUNCH BAG  BLACK SKULL., LUNCH BAG APPLE DESIGN)
# 372                                                          (JUMBO BAG RED RETROSPOT, JUMBO BAG APPLES)
# 373                                                        (JUMBO BAG ALPHABET, JUMBO BAG RED RETROSPOT)
# 374                                                                      (PARTY BUNTING, SPOTTY BUNTING)
# 375                                                    (JUMBO BAG VINTAGE LEAF, JUMBO BAG RED RETROSPOT)
# 376                                                                  (JUMBO BAG PEARS, JUMBO BAG APPLES)
# 377                              (GARDENERS KNEELING PAD KEEP CALM , GARDENERS KNEELING PAD CUP OF TEA )

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6, num_itemsets=20)

print("\nAssociation Rules:")
print(rules)
# Out:
# Association Rules:
#                                                             antecedents  \
# 0                                          (ALARM CLOCK BAKELIKE GREEN)
# 1                                           (ALARM CLOCK BAKELIKE RED )
# 2                                           (ALARM CLOCK BAKELIKE PINK)
# 3                                    (RED HANGING HEART T-LIGHT HOLDER)
# 4                                             (JUMBO BAG PINK POLKADOT)
# 5                                              (JUMBO STORAGE BAG SUKI)
# 6                     (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 7                                      (JUMBO  BAG BAROQUE BLACK WHITE)
# 8                                            (STRAWBERRY CHARLOTTE BAG)
# 9                                   (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 10                                               (JUMBO BAG STRAWBERRY)
# 11                                               (DOLLY GIRL LUNCH BOX)
# 12                                    (GREEN REGENCY TEACUP AND SAUCER)
# 13                                   (ROSES REGENCY TEACUP AND SAUCER )
# 14          (GREEN REGENCY TEACUP AND SAUCER, REGENCY CAKESTAND 3 TIER)
# 15         (ROSES REGENCY TEACUP AND SAUCER , REGENCY CAKESTAND 3 TIER)
# 16                                         (JUMBO BAG WOODLAND ANIMALS)
# 17                                             (WOODLAND CHARLOTTE BAG)
# 18                                        (CHARLOTTE BAG PINK POLKADOT)
# 19                                                     (DOTCOM POSTAGE)
# 20                                          (JUMBO BAG SPACEBOY DESIGN)
# 21                                    (GREEN REGENCY TEACUP AND SAUCER)
# 22                                     (PINK REGENCY TEACUP AND SAUCER)
# 23                                     (PINK REGENCY TEACUP AND SAUCER)
# 24  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENCY TEACUP AND SAUCER )
# 25    (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY TEACUP AND SAUCER)
# 26   (ROSES REGENCY TEACUP AND SAUCER , PINK REGENCY TEACUP AND SAUCER)
# 27                                     (PINK REGENCY TEACUP AND SAUCER)
# 28                                (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)
# 29                                                    (JUMBO BAG PEARS)
# 30                                 (GARDENERS KNEELING PAD CUP OF TEA )
#
#                                                             consequents  \
# 0                                           (ALARM CLOCK BAKELIKE RED )
# 1                                          (ALARM CLOCK BAKELIKE GREEN)
# 2                                           (ALARM CLOCK BAKELIKE RED )
# 3                                  (WHITE HANGING HEART T-LIGHT HOLDER)
# 4                                             (JUMBO BAG RED RETROSPOT)
# 5                                             (JUMBO BAG RED RETROSPOT)
# 6                                             (JUMBO BAG RED RETROSPOT)
# 7                                             (JUMBO BAG RED RETROSPOT)
# 8                                         (RED RETROSPOT CHARLOTTE BAG)
# 9                                     (PAPER CHAIN KIT 50'S CHRISTMAS )
# 10                                            (JUMBO BAG RED RETROSPOT)
# 11                                                (SPACEBOY LUNCH BOX )
# 12                                   (ROSES REGENCY TEACUP AND SAUCER )
# 13                                    (GREEN REGENCY TEACUP AND SAUCER)
# 14                                   (ROSES REGENCY TEACUP AND SAUCER )
# 15                                    (GREEN REGENCY TEACUP AND SAUCER)
# 16                                            (JUMBO BAG RED RETROSPOT)
# 17                                        (RED RETROSPOT CHARLOTTE BAG)
# 18                                        (RED RETROSPOT CHARLOTTE BAG)
# 19                                            (JUMBO BAG RED RETROSPOT)
# 20                                            (JUMBO BAG RED RETROSPOT)
# 21                                     (PINK REGENCY TEACUP AND SAUCER)
# 22                                    (GREEN REGENCY TEACUP AND SAUCER)
# 23                                   (ROSES REGENCY TEACUP AND SAUCER )
# 24                                     (PINK REGENCY TEACUP AND SAUCER)
# 25                                   (ROSES REGENCY TEACUP AND SAUCER )
# 26                                    (GREEN REGENCY TEACUP AND SAUCER)
# 27  (GREEN REGENCY TEACUP AND SAUCER, ROSES REGENCY TEACUP AND SAUCER )
# 28                                            (JUMBO BAG RED RETROSPOT)
# 29                                                   (JUMBO BAG APPLES)
# 30                                  (GARDENERS KNEELING PAD KEEP CALM )
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.049098            0.052655  0.032064    0.653061  12.402571
# 1             0.052655            0.049098  0.032064    0.608944  12.402571
# 2             0.039228            0.052655  0.023547    0.600255  11.399713
# 3             0.037124            0.113026  0.024800    0.668016   5.910285
# 4             0.061022            0.104659  0.041333    0.677340   6.471855
# 5             0.059319            0.104659  0.036273    0.611486   5.842638
# 6             0.025802            0.104659  0.020691    0.801942   7.662402
# 7             0.046743            0.104659  0.029309    0.627010   5.990959
# 8             0.036172            0.051703  0.024349    0.673130  13.019068
# 9             0.041082            0.058116  0.027655    0.673171  11.583179
# 10            0.041182            0.104659  0.026854    0.652068   6.230388
# 11            0.042585            0.045090  0.026954    0.632941  14.037229
# 12            0.050752            0.053357  0.038427    0.757157  14.190472
# 13            0.053357            0.050752  0.038427    0.720188  14.190472
# 14            0.025501            0.053357  0.020441    0.801572  15.022884
# 15            0.026303            0.050752  0.020441    0.777143  15.312706
# 16            0.043236            0.104659  0.026804    0.619930   5.923318
# 17            0.041733            0.051703  0.025301    0.606242  11.725388
# 18            0.037174            0.051703  0.026152    0.703504  13.606532
# 19            0.035371            0.104659  0.024299    0.686969   6.563857
# 20            0.034369            0.104659  0.021493    0.625364   5.975239
# 21            0.050752            0.038327  0.031663    0.623889  16.278213
# 22            0.038327            0.050752  0.031663    0.826144  16.278213
# 23            0.038327            0.053357  0.029960    0.781699  14.650440
# 24            0.038427            0.038327  0.027104    0.705346  18.403524
# 25            0.031663            0.053357  0.027104    0.856013  16.043204
# 26            0.029960            0.050752  0.027104    0.904682  17.825724
# 27            0.038327            0.038427  0.027104    0.707190  18.403524
# 28            0.033166            0.104659  0.022445    0.676737   6.466096
# 29            0.029810            0.048998  0.020341    0.682353  13.926140
# 30            0.037976            0.045741  0.027355    0.720317  15.747557
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                1.0  0.029479    2.730582       0.966842  0.460101
# 1                1.0  0.029479    2.431625       0.970472  0.460101
# 2                1.0  0.021482    2.369875       0.949527  0.344575
# 3                1.0  0.020604    2.671739       0.862836  0.197842
# 4                1.0  0.034946    2.774873       0.900431  0.332393
# 5                1.0  0.030064    2.304529       0.881111  0.284033
# 6                1.0  0.017991    4.520593       0.892521  0.188498
# 7                1.0  0.024416    2.400439       0.873932  0.240049
# 8                1.0  0.022478    2.901145       0.957837  0.383281
# 9                1.0  0.025268    2.881883       0.952811  0.386555
# 10               1.0  0.022544    2.573322       0.875554  0.225684
# 11               1.0  0.025034    2.601517       0.970072  0.443894
# 12               1.0  0.035719    3.898169       0.979227  0.585050
# 13               1.0  0.035719    3.392448       0.981922  0.585050
# 14               1.0  0.019080    4.770707       0.957861  0.349914
# 15               1.0  0.019106    4.259448       0.959944  0.361062
# 16               1.0  0.022279    2.355729       0.868737  0.221349
# 17               1.0  0.023143    2.408326       0.954552  0.371324
# 18               1.0  0.024230    3.198346       0.962278  0.416933
# 19               1.0  0.020597    2.860229       0.878732  0.209957
# 20               1.0  0.017896    2.389898       0.862278  0.182864
# 21               1.0  0.029718    2.556890       0.988749  0.551483
# 22               1.0  0.029718    5.459963       0.975974  0.551483
# 23               1.0  0.027915    4.336420       0.968876  0.485390
# 24               1.0  0.025631    3.263732       0.983454  0.545913
# 25               1.0  0.025415    6.574490       0.968329  0.467993
# 26               1.0  0.025584    9.958782       0.973054  0.505607
# 27               1.0  0.025631    3.283944       0.983351  0.545913
# 28               1.0  0.018974    2.769699       0.874346  0.194529
# 29               1.0  0.018880    2.993895       0.956712  0.347901
# 30               1.0  0.025618    3.411924       0.973466  0.485333
#
#     certainty  kulczynski
# 0    0.633778    0.631003
# 1    0.588752    0.631003
# 2    0.578037    0.523724
# 3    0.625712    0.443716
# 4    0.639623    0.536133
# 5    0.566072    0.479032
# 6    0.778790    0.499822
# 7    0.583410    0.453524
# 8    0.655308    0.572030
# 9    0.653005    0.574516
# 10   0.611397    0.454325
# 11   0.615609    0.615359
# 12   0.743469    0.738672
# 13   0.705228    0.738672
# 14   0.790387    0.592335
# 15   0.765228    0.589953
# 16   0.575503    0.438017
# 17   0.584774    0.547792
# 18   0.687338    0.604659
# 19   0.650378    0.459569
# 20   0.581572    0.415363
# 21   0.608900    0.725017
# 22   0.816849    0.725017
# 23   0.769395    0.671601
# 24   0.693602    0.706268
# 25   0.847897    0.681997
# 26   0.899586    0.719370
# 27   0.695488    0.706268
# 28   0.638950    0.445597
# 29   0.665987    0.548743
# 30   0.706910    0.659173
